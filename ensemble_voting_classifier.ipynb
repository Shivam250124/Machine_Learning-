# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivam250124/Machine_Learning-/blob/main/ensemble_voting_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2 align="center">Emsemble Learning: Voting Classifier</h2>

# %% [markdown]
# ### Problem Statement:  Classify raisins into one of the two categories,
# 1. Kecimen
# 1. Besni

# %%
import pandas as pd

df = pd.read_excel("Raisin_Dataset.xlsx")
df.sample(5)
# Out:
#       Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 362  64669       364.582804       228.800767      0.778561       67524
# 233  34559       264.515168       168.983057      0.769339       36516
# 572  93234       452.926506       268.763054      0.804913       97428
# 330  56837       368.372726       198.774656      0.841920       59040
# 405  50530       328.918015       198.283920      0.797864       52600
#
#        Extent  Perimeter    Class
# 362  0.655846    995.692  Kecimen
# 233  0.664187    750.365  Kecimen
# 572  0.715907   1222.886    Besni
# 330  0.634965    973.599  Kecimen
# 405  0.681696    897.796  Kecimen

# %%
df.shape
# Out:
# (900, 8)

# %% [markdown]
# There are total 900 records and using all the features that we have available, we will build a classification model by using support vector machine

# %% [markdown]
# ### Train Test Split

# %%
X = df[["Area", "MajorAxisLength", "MinorAxisLength", "Eccentricity", "ConvexArea", "Extent", "Perimeter"]]
y = df["Class"]

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %% [markdown]
# ### Model Training Using SVM: RBF Kernel

# %%
from sklearn.svm import SVC

model = SVC(kernel="rbf")
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

from sklearn.metrics import classification_report

report = classification_report(y_test, y_pred)
print(report)

model.n_iter_
# Out:
#               precision    recall  f1-score   support
#
#        Besni       0.86      0.75      0.80        83
#      Kecimen       0.81      0.90      0.85        97
#
#     accuracy                           0.83       180
#    macro avg       0.83      0.82      0.82       180
# weighted avg       0.83      0.83      0.83       180
# array([229], dtype=int32)

# %% [markdown]
# ### Train different models and use majority voting

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# Create different models
log_model = LogisticRegression()
dt_model = DecisionTreeClassifier()
svm_model = SVC(probability=True)

# Create a voting classifier
voting_clf = VotingClassifier(
    estimators=[('lr', log_model), ('dt', dt_model), ('svm', svm_model)],
    voting='hard')  # Use 'soft' for soft voting

voting_clf.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# VotingClassifier(estimators=[('lr', LogisticRegression()),
#                              ('dt', DecisionTreeClassifier()),
#                              ('svm', SVC(probability=True))])

# %%
y_pred = voting_clf.predict(X_test)

report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        Besni       0.92      0.83      0.87        83
#      Kecimen       0.87      0.94      0.90        97
#
#     accuracy                           0.89       180
#    macro avg       0.89      0.88      0.89       180
# weighted avg       0.89      0.89      0.89       180

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# Create different models
log_model1 = LogisticRegression()
dt_model1 = DecisionTreeClassifier()
svm_model1 = SVC(probability=True)

# Create a voting classifier
voting_clf1 = VotingClassifier(
    estimators=[('lr', log_model), ('dt', dt_model), ('svm', svm_model)],
    voting='soft')  # Use 'soft' for soft voting

voting_clf1.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# VotingClassifier(estimators=[('lr', LogisticRegression()),
#                              ('dt', DecisionTreeClassifier()),
#                              ('svm', SVC(probability=True))],
#                  voting='soft')

# %%
y_pred1 = voting_clf1.predict(X_test)

report1 = classification_report(y_test, y_pred)
print(report1)
# Out:
#               precision    recall  f1-score   support
#
#        Besni       0.92      0.82      0.87        83
#      Kecimen       0.86      0.94      0.90        97
#
#     accuracy                           0.88       180
#    macro avg       0.89      0.88      0.88       180
# weighted avg       0.89      0.88      0.88       180
