# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivam250124/Machine_Learning-/blob/main/ensemble_random_forest_raisin_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2 align="center">Random Forest</h2>

# %% [markdown]
# ### Problem Statement:  Classify raisins into one of the two categories,
# 1. Kecimen
# 1. Besni

# %%
import pandas as pd

df = pd.read_excel("Raisin_Dataset.xlsx")
df.sample(5)
# Out:
#        Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 271   84057       452.775695       245.219982      0.840641       86710
# 206   38585       274.445078       180.957559      0.751829       39926
# 795   72924       434.222666       220.491764      0.861484       77356
# 673   99177       494.055192       260.973648      0.849103      104468
# 505  102569       515.395249       259.194228      0.864342      106888
#
#        Extent  Perimeter    Class
# 271  0.622018   1179.024  Kecimen
# 206  0.696593    762.439  Kecimen
# 795  0.621603   1183.236    Besni
# 673  0.614175   1317.687    Besni
# 505  0.573242   1331.797    Besni

# %%
df.shape
# Out:
# (900, 8)

# %% [markdown]
# There are total 900 records and using all the features that we have available, we will build a classification model by using support vector machine

# %% [markdown]
# ### Train Test Split

# %%
X = df[["Area", "MajorAxisLength", "MinorAxisLength", "Eccentricity", "ConvexArea", "Extent", "Perimeter"]]
y = df["Class"]

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# %% [markdown]
# ### Model Training Using SVM: RBF Kernel

# %%
from sklearn.svm import SVC

model = SVC(kernel="rbf")
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

from sklearn.metrics import classification_report

report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        Besni       0.88      0.78      0.83        97
#      Kecimen       0.78      0.88      0.82        83
#
#     accuracy                           0.83       180
#    macro avg       0.83      0.83      0.83       180
# weighted avg       0.83      0.83      0.83       180

# %% [markdown]
# ### Model Training Using DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

from sklearn.metrics import classification_report

report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        Besni       0.81      0.88      0.84        97
#      Kecimen       0.84      0.76      0.80        83
#
#     accuracy                           0.82       180
#    macro avg       0.82      0.82      0.82       180
# weighted avg       0.82      0.82      0.82       180

# %% [markdown]
# ### Model Training Using RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=20)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

from sklearn.metrics import classification_report

report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        Besni       0.88      0.88      0.88        97
#      Kecimen       0.86      0.86      0.86        83
#
#     accuracy                           0.87       180
#    macro avg       0.87      0.87      0.87       180
# weighted avg       0.87      0.87      0.87       180

# %% [markdown]
# You can see that the model performance is better compared to SVM and DecisionTree
