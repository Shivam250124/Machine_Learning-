# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivam250124/Machine_Learning-/blob/main/emsemble_voting_regressor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2 align="center">Ensemble Learning: Voting Regressor<h2>

# %%
import pandas as pd

df = pd.read_csv("regression_home_prices.csv")
df
# Out:
#      area_sqr_ft  price_lakhs  bedrooms
# 0          656.0         39.0         2
# 1         1260.0         83.2         2
# 2         1057.0         86.6         3
# 3         1259.0         59.0         2
# 4         1800.0        140.0         3
# ..           ...          ...       ...
# 195       1412.0         71.0         2
# 196       1140.0         67.0         2
# 197       1501.0         80.0         2
# 198       1408.0         69.0         2
# 199       1198.0         56.0         2
#
# [200 rows x 3 columns]

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split

X = df[["area_sqr_ft","bedrooms"]]
y = df["price_lakhs"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %% [markdown]
# ### Let us now train the machine learning model using Linear Regression

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.8874887686858772

# %%
model.predict(X_test[:3])
# Out:
# array([79.15940002, 70.96469522, 63.51496358])

# %%
y_test[:3].to_list()
# Out:
# [68.0, 80.1, 69.0]

# %% [markdown]
# ### Now use voting regressor

# %%
from sklearn.ensemble import VotingRegressor

from sklearn.linear_model import LinearRegression, Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR


# Create different regression models
lin_reg = LinearRegression()
ridge_reg = Ridge(alpha=1.0)
dt_reg = DecisionTreeRegressor()
svr_reg = SVR()


# Create a voting regressor with the different models


vr = VotingRegressor(estimators=[
    ('lr', lin_reg),
    ('rr', ridge_reg),
    ('dr', dt_reg),
    ('svr', svr_reg)
])

vr.fit(X_train, y_train)
vr.score(X_test, y_test)
# Out:
# 0.8766422096603342

# %% [markdown]
# ### Prediction on sample data

# %%
vr.predict(X_test[:3])
# Out:
# array([80.39082643, 71.24976088, 66.09551567])

# %%
y_test[:3].to_list()
# Out:
# [68.0, 80.1, 69.0]
